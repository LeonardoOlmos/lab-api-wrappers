# %% [markdown]
# # Lab | API Wrappers

# %%
from config import client_id, client_secret

import pandas as pd
import numpy as np
import spotipy
import json
import pprint
import time

from spotipy.oauth2 import SpotifyClientCredentials

# %%
songs_df = pd.read_csv('./top10s.csv', encoding='latin-1')

# %%
songs_df = songs_df[['title', 'artist']]

# %%
songs_df
# Out:
#                                                  title            artist
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
# [603 rows x 2 columns]

# %%
# Create spotipy instance

sp = spotipy.Spotify(auth_manager= SpotifyClientCredentials(client_id = client_id, client_secret = client_secret))

# %%
def get_song_info(songs):
    ids = []
    
    for i in range(50):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(50,100):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(100, 150):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(150, 200):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(200, 250):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(250, 300):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(300, 350):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(350, 400):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(400, 450):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(450, 500):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(500, 550):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(550, 600):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    time.sleep(35)
    for i in range(600, len(songs_df)):
        try :
            song_info = sp.search(q = songs[i], type = "track", limit = 1)
            ids.append(song_info['tracks']['items'][0]['id'])
        except:
            ids.append(np.NaN)
    
    return ids

# %%
songs_names = list(songs_df.iloc[:]['title'])

# %%
songs_ids = get_song_info(songs_names)

# %%
len(songs_ids)
# Out:
# 603

# %%
songs_df['id'] = songs_ids

# %%
songs_df.isna().sum()
# Out:
# title     0
# artist    0
# id        2
# dtype: int64

# %%
songs_df[songs_df['id'].isna()]
# Out:
#      title          artist   id
# 50   Hello  Martin Solveig  NaN
# 297  43776         Beyoncé  NaN

# %%
songs_df = songs_df.dropna().reset_index(drop=True)

# %%
songs_df
# Out:
#                                                  title            artist
# 0                                     Hey, Soul Sister             Train  \
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 596                Find U Again (feat. Camila Cabello)       Mark Ronson
# 597      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 598  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 599    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 600                                   Kills You Slowly  The Chainsmokers
#
#                          id
# 0    4HlFJV71xXKIGcU3kRyttv
# 1    15JINEqzVMv3SvJTAXAKED
# ...

# %%
def get_features_by_song_id(songs_lst):
    features = []
            
    for i in range(50):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(50,100):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(100, 150):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(150, 200):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(200, 250):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(250, 300):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(300, 350):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(350, 400):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(400, 450):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(450, 500):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(500, 550):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(550, 600):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
    time.sleep(35)
    for i in range(600, len(songs_df)):
        try :
            features.append(sp.audio_features(songs_lst[i]))
        except:
            features.append([])
        
    return features

# %%
songs_ids = list(songs_df.loc[:]['id'])

# %%
songs_ids
# Out:
# ['4HlFJV71xXKIGcU3kRyttv',
#  '15JINEqzVMv3SvJTAXAKED',
#  '0HPD5WQqrq7wPWR7P7Dw1i',
#  '0SiywuOBRcynK0uKGWdCnn',
#  '7BqBn9nzAq8spo5e7cZ0dJ',
#  '5iDNf2uMgRzmQpcmGAzOUk',
#  '1DqdF42leyFIzqNDv9CjId',
#  '2xB46Bj9HZ4cr058yN4Pla',
#  '5sra5UY6sD658OabHL3QtI',
#  '2ENexcMEMsYk0rVJigVD3i',
#  '6ebkx7Q5tTxrCxKq4GYj0Y',
#  '22PMfvdz35fFKYnJyMn077',
#  '2V4bv1fNWfTcyRJKmej6Sj',
#  '0JIMT9gzLIIz0esKLyjbKf',
#  '4DvhkX2ic4zWkQeWMwQ2qf',
#  '1bM50INir8voAkVoKuvEUI',
#  '45O0tUN9Bh6LH4eNxQ07AT',
#  '7vWFaMq63AwkFDhS2OAg5u',
#  '4lwavw59UjXUPJZtKNdFYp',
#  '6vc2Jq2vaGu8z326kSrw92',
#  '6wOYnPq1hPihRepcDClPUw',
#  '2rDwdvBma1O1eLzo29p2cr',
#  '7zp9FOU4cjFdGN1zdWTvcB',
#  '6SpLc7EXZIPpy0sVko0aoU',
#  '5XRHGXut00SrJUFmcn2lQF',
#  '1fBl642IhJOE5U319Gy2Go',
#  '1YaVmBh7EAeR54FIjuFcb5',
#  '58q2HKrzhC3ozto2nDdN4z',
#  '5jzKL4BDMClWqRguW5qZvh',
#  '6KOEK6SeCEZOQkLj5M1PxH',
#  '5cc9Zbfp9u10sfJeKZ3h16',
#  '17tDv8WA8IhqE8qzuQn707',
#  '7lWUJpax919G4JdaFEVmCy',
#  '0oJMv049q8hEkes9w0L1J4',
# ...

# %%
len(songs_ids)
# Out:
# 601

# %%
features = get_features_by_song_id(songs_ids)

# %%
features
# Out:
# [[],
#  [{'danceability': 0.749,
#    'energy': 0.925,
#    'key': 10,
#    'loudness': -5.034,
#    'mode': 1,
#    'speechiness': 0.227,
#    'acousticness': 0.241,
#    'instrumentalness': 0,
#    'liveness': 0.52,
#    'valence': 0.641,
#    'tempo': 86.989,
#    'type': 'audio_features',
#    'id': '15JINEqzVMv3SvJTAXAKED',
#    'uri': 'spotify:track:15JINEqzVMv3SvJTAXAKED',
#    'track_href': 'https://api.spotify.com/v1/tracks/15JINEqzVMv3SvJTAXAKED',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15JINEqzVMv3SvJTAXAKED',
#    'duration_ms': 263373,
#    'time_signature': 4}],
#  [{'danceability': 0.755,
#    'energy': 0.837,
#    'key': 2,
#    'loudness': -2.718,
#    'mode': 0,
#    'speechiness': 0.142,
#    'acousticness': 0.0991,
#    'instrumentalness': 0,
#    'liveness': 0.289,
#    'valence': 0.714,
#    'tempo': 120.028,
#    'type': 'audio_features',
#    'id': '0HPD5WQqrq7wPWR7P7Dw1i',
#    'uri': 'spotify:track:0HPD5WQqrq7wPWR7P7Dw1i',
# ...

# %%
len(features)
# Out:
# 601

# %%
flattened_data = [item for sublist in features for item in sublist]

# %%
flattened_data
# Out:
# [{'danceability': 0.749,
#   'energy': 0.925,
#   'key': 10,
#   'loudness': -5.034,
#   'mode': 1,
#   'speechiness': 0.227,
#   'acousticness': 0.241,
#   'instrumentalness': 0,
#   'liveness': 0.52,
#   'valence': 0.641,
#   'tempo': 86.989,
#   'type': 'audio_features',
#   'id': '15JINEqzVMv3SvJTAXAKED',
#   'uri': 'spotify:track:15JINEqzVMv3SvJTAXAKED',
#   'track_href': 'https://api.spotify.com/v1/tracks/15JINEqzVMv3SvJTAXAKED',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15JINEqzVMv3SvJTAXAKED',
#   'duration_ms': 263373,
#   'time_signature': 4},
#  {'danceability': 0.755,
#   'energy': 0.837,
#   'key': 2,
#   'loudness': -2.718,
#   'mode': 0,
#   'speechiness': 0.142,
#   'acousticness': 0.0991,
#   'instrumentalness': 0,
#   'liveness': 0.289,
#   'valence': 0.714,
#   'tempo': 120.028,
#   'type': 'audio_features',
#   'id': '0HPD5WQqrq7wPWR7P7Dw1i',
#   'uri': 'spotify:track:0HPD5WQqrq7wPWR7P7Dw1i',
# ...

# %%
features_df = pd.DataFrame(flattened_data)

# %%
features_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.749   0.925   10    -5.034     1       0.2270       0.24100  \
# 1         0.755   0.837    2    -2.718     0       0.1420       0.09910
# 2         0.696   0.921    0    -3.755     1       0.0363       0.00314
# 3         0.635   0.841    5    -5.379     1       0.0422       0.01340
# 4         0.643   0.766    4    -7.670     0       0.1450       0.19800
#
#    instrumentalness  liveness  valence    tempo            type
# 0          0.000000    0.5200    0.641   86.989  audio_features  \
# 1          0.000000    0.2890    0.714  120.028  audio_features
# 2          0.000052    0.0842    0.714  119.001  audio_features
# 3          0.000000    0.0622    0.424  109.021  audio_features
# 4          0.000008    0.1400    0.350  141.986  audio_features
#
#                        id                                   uri
# 0  15JINEqzVMv3SvJTAXAKED  spotify:track:15JINEqzVMv3SvJTAXAKED  \
# ...

# %%
def get_songs_dataframe(songs_df, features_df):
    merged_df = pd.concat([songs_df, features_df], axis = 1)
    
    return merged_df

# %%
data = get_songs_dataframe(songs_df, features_df)

# %%
data.head()
# Out:
#                   title      artist                      id  danceability
# 0      Hey, Soul Sister       Train  4HlFJV71xXKIGcU3kRyttv         0.749  \
# 1  Love The Way You Lie      Eminem  15JINEqzVMv3SvJTAXAKED         0.755
# 2               TiK ToK       Kesha  0HPD5WQqrq7wPWR7P7Dw1i         0.696
# 3           Bad Romance   Lady Gaga  0SiywuOBRcynK0uKGWdCnn         0.635
# 4  Just the Way You Are  Bruno Mars  7BqBn9nzAq8spo5e7cZ0dJ         0.643
#
#    energy   key  loudness  mode  speechiness  acousticness  ...  liveness
# 0   0.925  10.0    -5.034   1.0       0.2270       0.24100  ...    0.5200  \
# 1   0.837   2.0    -2.718   0.0       0.1420       0.09910  ...    0.2890
# 2   0.921   0.0    -3.755   1.0       0.0363       0.00314  ...    0.0842
# 3   0.841   5.0    -5.379   1.0       0.0422       0.01340  ...    0.0622
# 4   0.766   4.0    -7.670   0.0       0.1450       0.19800  ...    0.1400
#
#    valence    tempo            type                      id
# ...

# %%
data.shape
# Out:
# (601, 21)

# %%
data[data['title'].isna()]
# Out:
# Empty DataFrame
# Columns: [title, artist, id, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.to_csv('../lab-api-wrappers/features_songs.csv', index=False)
